# %%
from somemodule import get_preprocessor()

# In order to choose best preprocessor, we have to:
# 1) Define test image or even a dataloader to choose on what picture to train
# 2) Define OCR model (optionally) in order to rely on realistic ocr performance, not only picture quality
# 3) Define preprocessing pipelines and parameters to compare
#
# I want to pass all of them by myself, making somemodule universal for different applications
#
#
my_best_preprocessor = get_preprocessor(SCENARIOS, IMAGE ,OCR_MODEL)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 a = range(5)
# ----> 2 a.__contains__()
#
# TypeError: expected 1 argument, got 0
